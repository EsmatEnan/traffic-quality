# %%
# %reload_ext autoreload
# %autoreload 2

# load dependencies'
import pandas as pd
import geopandas as gpd


from envirocar import TrackAPI, DownloadClient, BboxSelector, ECConfig

# create an initial but optional config and an api client
config = ECConfig()
track_api = TrackAPI(api_client=DownloadClient(config=config))

# %%
bbox = BboxSelector([
    7.601165771484375, # min_x
    51.94807412325402, # min_y
    7.648200988769531, # max_x
    51.97261482608728  # max_y
])

# issue a query
track_df = track_api.get_tracks(bbox=bbox, num_results=50) # requesting 50 tracks inside the bbox
track_df
# Out:
#                            id                 time                  geometry  \
# 0    5eb7582165b80c5d6be69f24  2020-05-09T21:10:46  POINT (7.65180 51.95396)
# 1    5eb7582165b80c5d6be69f26  2020-05-09T21:10:51  POINT (7.65169 51.95395)
# 2    5eb7582165b80c5d6be69f27  2020-05-09T21:10:56  POINT (7.65148 51.95395)
# 3    5eb7582165b80c5d6be69f28  2020-05-09T21:11:01  POINT (7.65127 51.95397)
# 4    5eb7582165b80c5d6be69f29  2020-05-09T21:11:06  POINT (7.65101 51.95396)
# ..                        ...                  ...                       ...
# 195  5dc985eb44ea856b702dd986  2019-10-29T16:10:53  POINT (7.59827 51.96493)
# 196  5dc985eb44ea856b702dd987  2019-10-29T16:10:58  POINT (7.59737 51.96492)
# 197  5dc985eb44ea856b702dd988  2019-10-29T16:11:03  POINT (7.59646 51.96492)
# 198  5dc985eb44ea856b702dd989  2019-10-29T16:11:08  POINT (7.59541 51.96499)
# 199  5dc985eb44ea856b702dd98a  2019-10-29T16:11:13  POINT (7.59433 51.96506)
#
#      Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                  16.000000                      %   6.060965     kg/h
# 1                  16.831018                      %   7.644530     kg/h
# 2                  16.846021                      %   6.152178     kg/h
# 3                  17.000001                      %   7.380207     kg/h
# 4                  15.151858                      %   3.983817     kg/h
# ..                       ...                    ...        ...      ...
# 195                16.027855                      %   8.579484     kg/h
# 196                14.000000                      %   4.308154     kg/h
# 197                32.000001                      %  18.595897     kg/h
# 198                16.000000                      %   7.105633     kg/h
# 199                16.910762                      %   7.694858     kg/h
#
#      GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ...  \
# 0          1.000000     precision         244.006986  ...
# 1          1.000000     precision         273.231882  ...
# 2          1.000000     precision         273.377388  ...
# 3          0.930191     precision         274.705621  ...
# 4          1.000000     precision         275.181028  ...
# ..              ...           ...                ...  ...
# 195        1.016152     precision         269.728716  ...
# 196        1.015842     precision         268.303093  ...
# 197        1.100000     precision         273.328479  ...
# 198        1.267463     precision         276.193063  ...
# 199        0.938076     precision         276.065524  ...
#
#     sensor.constructionYear  sensor.manufacturer track.appVersion  \
# 0                      2007                Dodge              NaN
# 1                      2007                Dodge              NaN
# 2                      2007                Dodge              NaN
# 3                      2007                Dodge              NaN
# 4                      2007                Dodge              NaN
# ..                      ...                  ...              ...
# 195                    2004        Mercedes Benz              NaN
# 196                    2004        Mercedes Benz              NaN
# 197                    2004        Mercedes Benz              NaN
# 198                    2004        Mercedes Benz              NaN
# 199                    2004        Mercedes Benz              NaN
#
#      track.touVersion O2 Lambda Voltage ER.value  O2 Lambda Voltage ER.unit  \
# 0                 NaN                        NaN                        NaN
# 1                 NaN                        NaN                        NaN
# 2                 NaN                        NaN                        NaN
# 3                 NaN                        NaN                        NaN
# 4                 NaN                        NaN                        NaN
# ..                ...                        ...                        ...
# 195               NaN                        NaN                        NaN
# 196               NaN                        NaN                        NaN
# 197               NaN                        NaN                        NaN
# 198               NaN                        NaN                        NaN
# 199               NaN                        NaN                        NaN
#
#     MAF.value  MAF.unit O2 Lambda Voltage.value  O2 Lambda Voltage.unit
# 0         NaN       NaN                     NaN                     NaN
# 1         NaN       NaN                     NaN                     NaN
# 2         NaN       NaN                     NaN                     NaN
# 3         NaN       NaN                     NaN                     NaN
# 4         NaN       NaN                     NaN                     NaN
# ..        ...       ...                     ...                     ...
# 195       NaN       NaN                     NaN                     NaN
# 196       NaN       NaN                     NaN                     NaN
# 197       NaN       NaN                     NaN                     NaN
# 198       NaN       NaN                     NaN                     NaN
# 199       NaN       NaN                     NaN                     NaN
#
# [9670 rows x 54 columns]

# %%
#some_track = track_df.loc[[30,31,34,32,33,37]]
some_track_id30 = track_df['track.id'].unique()[30]
track_30 = track_df[track_df['track.id'] == some_track_id30]


some_track_id31 = track_df['track.id'].unique()[31]
track_31 = track_df[track_df['track.id'] == some_track_id31]


some_track_id32 = track_df['track.id'].unique()[32]
track_32 = track_df[track_df['track.id'] == some_track_id32]


some_track_id33 = track_df['track.id'].unique()[33]
track_33 = track_df[track_df['track.id'] == some_track_id33]


some_track_id34 = track_df['track.id'].unique()[34]
track_34 = track_df[track_df['track.id'] == some_track_id34]


some_track_id38 = track_df['track.id'].unique()[38]
track_38 = track_df[track_df['track.id'] == some_track_id38]

some_track_id39 = track_df['track.id'].unique()[39]
track_39 = track_df[track_df['track.id'] == some_track_id39]

some_track_id40 = track_df['track.id'].unique()[40]
track_40 = track_df[track_df['track.id'] == some_track_id40]

some_track_id45 = track_df['track.id'].unique()[45]
track_45 = track_df[track_df['track.id'] == some_track_id45]

df_row_reindex = pd.concat([track_30, track_31, track_32, track_33, track_34, track_38, track_39, track_40, track_45], ignore_index=True)

df_row_reindex
# Out:
#                             id                 time                  geometry  \
# 0     5de9d7a03bdb691868e765cf  2019-11-27T14:56:33  POINT (7.65039 51.94099)
# 1     5de9d7a03bdb691868e765d1  2019-11-27T14:56:38  POINT (7.65039 51.94099)
# 2     5de9d7a03bdb691868e765d2  2019-11-27T14:56:43  POINT (7.65036 51.94100)
# 3     5de9d7a03bdb691868e765d3  2019-11-27T14:56:48  POINT (7.65004 51.94121)
# 4     5de9d7a03bdb691868e765d4  2019-11-27T14:56:53  POINT (7.64947 51.94158)
# ...                        ...                  ...                       ...
# 1738  5dd68ae544ea856b70e135f5  2019-11-18T08:28:53  POINT (7.65511 51.93745)
# 1739  5dd68ae544ea856b70e135f6  2019-11-18T08:28:58  POINT (7.65579 51.93697)
# 1740  5dd68ae544ea856b70e135f7  2019-11-18T08:29:03  POINT (7.65634 51.93661)
# 1741  5dd68ae544ea856b70e135f8  2019-11-18T08:29:08  POINT (7.65630 51.93626)
# 1742  5dd68ae544ea856b70e135f9  2019-11-18T08:29:13  POINT (7.65569 51.93589)
#
#       Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                   13.000000                      %   2.607777     kg/h
# 1                   13.336957                      %   3.528991     kg/h
# 2                   18.098877                      %  11.026625     kg/h
# 3                   20.248292                      %  14.895779     kg/h
# 4                   16.918660                      %  10.951059     kg/h
# ...                       ...                    ...        ...      ...
# 1738                16.114791                      %   5.919913     kg/h
# 1739                13.000000                      %   2.594088     kg/h
# 1740                13.000000                      %   2.612751     kg/h
# 1741                21.234414                      %  13.953334     kg/h
# 1742                16.115681                      %   5.305019     kg/h
#
#       GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ...  \
# 0           1.212573     precision                NaN  ...
# 1           1.000000     precision                NaN  ...
# 2           1.000000     precision         316.235294  ...
# 3           1.042262     precision         316.572318  ...
# 4           1.033501     precision         314.128049  ...
# ...              ...           ...                ...  ...
# 1738        1.299901     precision         137.960404  ...
# 1739        1.286282     precision         137.876083  ...
# 1740        1.506910     precision         139.104511  ...
# 1741        1.577233     precision         216.239506  ...
# 1742        1.874468     precision         228.339801  ...
#
#      sensor.constructionYear  sensor.manufacturer track.appVersion  \
# 0                       2004        Mercedes Benz              NaN
# 1                       2004        Mercedes Benz              NaN
# 2                       2004        Mercedes Benz              NaN
# 3                       2004        Mercedes Benz              NaN
# 4                       2004        Mercedes Benz              NaN
# ...                      ...                  ...              ...
# 1738                    2004        Mercedes Benz              NaN
# 1739                    2004        Mercedes Benz              NaN
# 1740                    2004        Mercedes Benz              NaN
# 1741                    2004        Mercedes Benz              NaN
# 1742                    2004        Mercedes Benz              NaN
#
#       track.touVersion O2 Lambda Voltage ER.value  O2 Lambda Voltage ER.unit  \
# 0                  NaN                        NaN                        NaN
# 1                  NaN                        NaN                        NaN
# 2                  NaN                        NaN                        NaN
# 3                  NaN                        NaN                        NaN
# 4                  NaN                        NaN                        NaN
# ...                ...                        ...                        ...
# 1738               NaN                        NaN                        NaN
# 1739               NaN                        NaN                        NaN
# 1740               NaN                        NaN                        NaN
# 1741               NaN                        NaN                        NaN
# 1742               NaN                        NaN                        NaN
#
#      MAF.value  MAF.unit O2 Lambda Voltage.value  O2 Lambda Voltage.unit
# 0          NaN       NaN                     NaN                     NaN
# 1          NaN       NaN                     NaN                     NaN
# 2          NaN       NaN                     NaN                     NaN
# 3          NaN       NaN                     NaN                     NaN
# 4          NaN       NaN                     NaN                     NaN
# ...        ...       ...                     ...                     ...
# 1738       NaN       NaN                     NaN                     NaN
# 1739       NaN       NaN                     NaN                     NaN
# 1740       NaN       NaN                     NaN                     NaN
# 1741       NaN       NaN                     NaN                     NaN
# 1742       NaN       NaN                     NaN                     NaN
#
# [1743 rows x 54 columns]

# %%
df_row_reindex.to_csv('C:/Users/sindh/Documents/GitHub/Envirocar/Data.csv')

# %%
import folium

lats = list(df_row_reindex['geometry'].apply(lambda coord: coord.y))
lngs = list(df_row_reindex['geometry'].apply(lambda coord: coord.x))

avg_lat = sum(lats) / len(lats)
avg_lngs = sum(lngs) / len(lngs)

m = folium.Map(location=[avg_lat, avg_lngs], zoom_start=13)
folium.PolyLine([coords for coords in zip(lats, lngs)], color='blue').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
