# %% [markdown]
# # MapMatching Example for enviroCar Tracks

# %%
# %load_ext autoreload
# %autoreload 2

# load dependencies'
import pandas as pd
import geopandas as gpd

from envirocar import TrackAPI, DownloadClient, BboxSelector, ECConfig

# create an initial but optional config and an api client
config = ECConfig()
track_api = TrackAPI(api_client=DownloadClient(config=config))

# %%
bbox = BboxSelector([
    7.601165771484375, # min_x
    51.94807412325402, # min_y
    7.648200988769531, # max_x
    51.97261482608728  # max_y
])

# issue a query
track_df = track_api.get_tracks(bbox=bbox, num_results=50) # requesting 50 tracks inside the bbox
track_df
# Out:
#                            id                 time                  geometry  \
# 0    5eb7582165b80c5d6be69f24  2020-05-09T21:10:46  POINT (7.65180 51.95396)
# 1    5eb7582165b80c5d6be69f26  2020-05-09T21:10:51  POINT (7.65169 51.95395)
# 2    5eb7582165b80c5d6be69f27  2020-05-09T21:10:56  POINT (7.65148 51.95395)
# 3    5eb7582165b80c5d6be69f28  2020-05-09T21:11:01  POINT (7.65127 51.95397)
# 4    5eb7582165b80c5d6be69f29  2020-05-09T21:11:06  POINT (7.65101 51.95396)
# ..                        ...                  ...                       ...
# 195  5dc985eb44ea856b702dd986  2019-10-29T16:10:53  POINT (7.59827 51.96493)
# 196  5dc985eb44ea856b702dd987  2019-10-29T16:10:58  POINT (7.59737 51.96492)
# 197  5dc985eb44ea856b702dd988  2019-10-29T16:11:03  POINT (7.59646 51.96492)
# 198  5dc985eb44ea856b702dd989  2019-10-29T16:11:08  POINT (7.59541 51.96499)
# 199  5dc985eb44ea856b702dd98a  2019-10-29T16:11:13  POINT (7.59433 51.96506)
#
#      Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                  16.000000                      %   6.060965     kg/h
# 1                  16.831018                      %   7.644530     kg/h
# 2                  16.846021                      %   6.152178     kg/h
# 3                  17.000001                      %   7.380207     kg/h
# 4                  15.151858                      %   3.983817     kg/h
# ..                       ...                    ...        ...      ...
# 195                16.027855                      %   8.579484     kg/h
# 196                14.000000                      %   4.308154     kg/h
# 197                32.000001                      %  18.595897     kg/h
# 198                16.000000                      %   7.105633     kg/h
# 199                16.910762                      %   7.694858     kg/h
#
#      GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ...  \
# 0          1.000000     precision         244.006986  ...
# 1          1.000000     precision         273.231882  ...
# 2          1.000000     precision         273.377388  ...
# 3          0.930191     precision         274.705621  ...
# 4          1.000000     precision         275.181028  ...
# ..              ...           ...                ...  ...
# 195        1.016152     precision         269.728716  ...
# 196        1.015842     precision         268.303093  ...
# 197        1.100000     precision         273.328479  ...
# 198        1.267463     precision         276.193063  ...
# 199        0.938076     precision         276.065524  ...
#
#     sensor.constructionYear  sensor.manufacturer track.appVersion  \
# 0                      2007                Dodge              NaN
# 1                      2007                Dodge              NaN
# 2                      2007                Dodge              NaN
# 3                      2007                Dodge              NaN
# 4                      2007                Dodge              NaN
# ..                      ...                  ...              ...
# 195                    2004        Mercedes Benz              NaN
# 196                    2004        Mercedes Benz              NaN
# 197                    2004        Mercedes Benz              NaN
# 198                    2004        Mercedes Benz              NaN
# 199                    2004        Mercedes Benz              NaN
#
#      track.touVersion O2 Lambda Voltage ER.value  O2 Lambda Voltage ER.unit  \
# 0                 NaN                        NaN                        NaN
# 1                 NaN                        NaN                        NaN
# 2                 NaN                        NaN                        NaN
# 3                 NaN                        NaN                        NaN
# 4                 NaN                        NaN                        NaN
# ..                ...                        ...                        ...
# 195               NaN                        NaN                        NaN
# 196               NaN                        NaN                        NaN
# 197               NaN                        NaN                        NaN
# 198               NaN                        NaN                        NaN
# 199               NaN                        NaN                        NaN
#
#     MAF.value  MAF.unit O2 Lambda Voltage.value  O2 Lambda Voltage.unit
# 0         NaN       NaN                     NaN                     NaN
# 1         NaN       NaN                     NaN                     NaN
# 2         NaN       NaN                     NaN                     NaN
# 3         NaN       NaN                     NaN                     NaN
# 4         NaN       NaN                     NaN                     NaN
# ..        ...       ...                     ...                     ...
# 195       NaN       NaN                     NaN                     NaN
# 196       NaN       NaN                     NaN                     NaN
# 197       NaN       NaN                     NaN                     NaN
# 198       NaN       NaN                     NaN                     NaN
# 199       NaN       NaN                     NaN                     NaN
#
# [9670 rows x 54 columns]

# %%
some_track_id30 = track_df['track.id'].unique()[30]
track_30 = track_df[track_df['track.id'] == some_track_id30]


some_track_id31 = track_df['track.id'].unique()[31]
track_31 = track_df[track_df['track.id'] == some_track_id31]


some_track_id32 = track_df['track.id'].unique()[32]
track_32 = track_df[track_df['track.id'] == some_track_id32]


some_track_id33 = track_df['track.id'].unique()[33]
track_33 = track_df[track_df['track.id'] == some_track_id33]


some_track_id34 = track_df['track.id'].unique()[34]
track_34 = track_df[track_df['track.id'] == some_track_id34]


some_track_id38 = track_df['track.id'].unique()[38]
track_38 = track_df[track_df['track.id'] == some_track_id38]

some_track_id39 = track_df['track.id'].unique()[39]
track_39 = track_df[track_df['track.id'] == some_track_id39]

some_track_id40 = track_df['track.id'].unique()[40]
track_40 = track_df[track_df['track.id'] == some_track_id40]

some_track_id45 = track_df['track.id'].unique()[45]
track_45 = track_df[track_df['track.id'] == some_track_id45]

tracks = pd.concat([track_31, track_32, track_30], ignore_index=True)

tracks
# Out:
#                            id                 time                  geometry  \
# 0    5ddcdd4a44ea85025cfdf87a  2019-11-25T16:13:34  POINT (7.64831 51.94246)
# 1    5ddcdd4a44ea85025cfdf87c  2019-11-25T16:13:39  POINT (7.64831 51.94248)
# 2    5ddcdd4a44ea85025cfdf87d  2019-11-25T16:13:44  POINT (7.64808 51.94270)
# 3    5ddcdd4a44ea85025cfdf87e  2019-11-25T16:13:49  POINT (7.64769 51.94310)
# 4    5ddcdd4a44ea85025cfdf87f  2019-11-25T16:13:55  POINT (7.64738 51.94342)
# ..                        ...                  ...                       ...
# 694  5de9d7a03bdb691868e766d2  2019-11-27T15:18:25  POINT (7.58793 51.96553)
# 695  5de9d7a03bdb691868e766d3  2019-11-27T15:18:30  POINT (7.58722 51.96557)
# 696  5de9d7a03bdb691868e766d4  2019-11-27T15:18:36  POINT (7.58703 51.96558)
# 697  5de9d7a03bdb691868e766d5  2019-11-27T15:18:41  POINT (7.58691 51.96549)
# 698  5de9d7a03bdb691868e766d6  2019-11-27T15:18:46  POINT (7.58690 51.96534)
#
#      Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                  13.000000                      %   2.786892     kg/h
# 1                  20.891455                      %  10.765092     kg/h
# 2                  62.367647                      %  28.304836     kg/h
# 3                  13.000000                      %   2.944278     kg/h
# 4                  13.000000                      %   2.734270     kg/h
# ..                       ...                    ...        ...      ...
# 694                13.000000                      %   2.652628     kg/h
# 695                13.000000                      %   2.482738     kg/h
# 696                17.216216                      %   2.861668     kg/h
# 697                13.000000                      %   2.777937     kg/h
# 698                13.000000                      %   2.492268     kg/h
#
#      GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ...  \
# 0          0.900000     precision         326.011243  ...
# 1          0.953654     precision         329.524828  ...
# 2          0.900000     precision         325.714825  ...
# 3          0.958882     precision         328.816084  ...
# 4          1.000000     precision         325.877407  ...
# ..              ...           ...                ...  ...
# 694        1.484677     precision         276.066612  ...
# 695        1.201988     precision         273.991228  ...
# 696        1.765377     precision         273.961835  ...
# 697        1.741742     precision         183.879083  ...
# 698       28.861711     precision         188.895971  ...
#
#     sensor.constructionYear  sensor.manufacturer track.appVersion  \
# 0                      2004        Mercedes Benz              NaN
# 1                      2004        Mercedes Benz              NaN
# 2                      2004        Mercedes Benz              NaN
# 3                      2004        Mercedes Benz              NaN
# 4                      2004        Mercedes Benz              NaN
# ..                      ...                  ...              ...
# 694                    2004        Mercedes Benz              NaN
# 695                    2004        Mercedes Benz              NaN
# 696                    2004        Mercedes Benz              NaN
# 697                    2004        Mercedes Benz              NaN
# 698                    2004        Mercedes Benz              NaN
#
#      track.touVersion O2 Lambda Voltage ER.value  O2 Lambda Voltage ER.unit  \
# 0                 NaN                        NaN                        NaN
# 1                 NaN                        NaN                        NaN
# 2                 NaN                        NaN                        NaN
# 3                 NaN                        NaN                        NaN
# 4                 NaN                        NaN                        NaN
# ..                ...                        ...                        ...
# 694               NaN                        NaN                        NaN
# 695               NaN                        NaN                        NaN
# 696               NaN                        NaN                        NaN
# 697               NaN                        NaN                        NaN
# 698               NaN                        NaN                        NaN
#
#     MAF.value  MAF.unit O2 Lambda Voltage.value  O2 Lambda Voltage.unit
# 0         NaN       NaN                     NaN                     NaN
# 1         NaN       NaN                     NaN                     NaN
# 2         NaN       NaN                     NaN                     NaN
# 3         NaN       NaN                     NaN                     NaN
# 4         NaN       NaN                     NaN                     NaN
# ..        ...       ...                     ...                     ...
# 694       NaN       NaN                     NaN                     NaN
# 695       NaN       NaN                     NaN                     NaN
# 696       NaN       NaN                     NaN                     NaN
# 697       NaN       NaN                     NaN                     NaN
# 698       NaN       NaN                     NaN                     NaN
#
# [699 rows x 54 columns]

# %%
#tracks.to_csv('C:/Users/sindh/Documents/GitHub/data.csv')

# %% [markdown]
# ## Creating the Graph Network

# %%
# %%time
import numpy as np
import osmnx as ox

lat = 51.950296032982756
lng = 7.615756988525391

# Get the OSM graph of "drive" streets for münster an plot it
graph = ox.graph_from_point((lat, lng), distance=5000, network_type='drive')
ox.plot_graph(graph, fig_height=10, fig_width=10)
# Out:
# Wall time: 52.3 s
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x26f70366b48>)

# %%
from leuvenmapmatching.matcher.distance import DistanceMatcher
from leuvenmapmatching.map.inmem import InMemMap
from leuvenmapmatching.matcher.newsonkrumm import NewsonKrummMatcher

# Leuven Map Matching is using a different internal graph structure for the street data. 
# Therefore, the OSMnx graph needs to be transformed to the InMemMap
streetmap = InMemMap("enviroCar", use_latlon=True, use_rtree=True, index_edges=True)

# add nodes
nodes = list(graph.nodes)
for node in nodes:
    #if graph.nodes[node]['highway'] == 'traffic_signals':
    lng = graph.nodes[node]['x']
    lat = graph.nodes[node]['y']
    streetmap.add_node(node, (lat, lng))
    #print(graph.nodes[node]['highway'])

# add edges
edges = list(graph.edges)
for edge in edges:
    node_a, node_b = edge[0], edge[1]
    streetmap.add_edge(node_a, node_b)
    #print(graph.edges[edge]['name'])
    # exclude bi-directional edges when street is oneway
    if not graph.edges[edge]['oneway']:
        streetmap.add_edge(node_b, node_a)
    
streetmap.purge()
# Out:
# C:\Users\sindh\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\sindh\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ## MapMatch the Track

# %%
# Get the latitude and longitude coordinates from the track and join them in an array
lats = list(track_31['geometry'].apply(lambda coord: coord.y))
lngs = list(track_31['geometry'].apply(lambda coord: coord.x))

track_coords = [c for c in zip(lats, lngs)]

# %%
from leuvenmapmatching.matcher.simple import SimpleMatcher
# Configure the mapmatcher. For increasing the performance it is important 
# that max_dist (in meters) is not set too high
matcher = NewsonKrummMatcher(streetmap,
                          max_dist=100, 
                          max_dist_init=50,
                          beta = 1/0.2,
                          #non_emitting_length_factor=0.75,
                          obs_noise=100,
                          #obs_noise_ne=75,
                          dist_noise=5,
                          non_emitting_states=False,
                          non_emitting_edgeid=False)

# %%
# %%time 
# Perform the mapmatching 
edge_ids, last_idx = matcher.match(track_coords)
# Out:
# Wall time: 3.12 s

# %%
print(len(track_coords))
print(len(edge_ids))
# Out:
# 243
# 243

# %%
edge_ids
# Out:
# [(4017092106, 2705735628),
#  (4017092106, 2705735628),
#  (4017092106, 2705735628),
#  (2705735628, 278156525),
#  (278156525, 278156529),
#  (278156529, 278156537),
#  (278156537, 278156460),
#  (278156460, 29041433),
#  (278156460, 29041433),
#  (278156460, 29041433),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (29041433, 277898402),
#  (277898402, 277898418),
#  (277898402, 277898418),
#  (277898402, 277898418),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (277898418, 29041426),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (29041426, 277896979),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (277896979, 29041418),
#  (29041418, 29041414),
#  (29041418, 29041414),
#  (29041418, 29041414),
#  (29041418, 29041414),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (29041414, 277729693),
#  (277729693, 277738641),
#  (277738641, 277727478),
#  (277727478, 277727457),
#  (277727457, 54781716),
#  (54781716, 302697571),
#  (302697571, 302697583),
#  (302697583, 54781758),
#  (54781758, 256787271),
#  (256787271, 302697586),
#  (302697586, 254321187),
#  (254321187, 302697589),
#  (254321187, 302697589),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (302697589, 54781720),
#  (54781720, 303364981),
#  (54781720, 303364981),
#  (303364981, 304637903),
#  (303364981, 304637903),
#  (303364981, 304637903),
#  (303364981, 304637903),
#  (303364981, 304637903),
#  (304637903, 34924748),
#  (304637903, 34924748),
#  (304637903, 34924748),
#  (304637903, 34924748),
#  (304637903, 34924748),
#  (34924748, 34924790),
#  (34924748, 34924790),
#  (34924748, 34924790),
#  (34924748, 34924790),
#  (34924748, 34924790),
#  (34924748, 34924790),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (34924790, 7152154273),
#  (7152154273, 33846185),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (33846185, 60676690),
#  (60676690, 21518910),
#  (60676690, 21518910),
#  (60676690, 21518910),
#  (21518910, 6425072711),
#  (21518910, 6425072711),
#  (21518910, 6425072711),
#  (21518910, 6425072711),
#  (21518910, 6425072711),
#  (21518910, 6425072711),
#  (6425072711, 6425072705),
#  (6425072705, 945921131),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (945921131, 29041398),
#  (29041398, 37703158),
#  (37703158, 249810646),
#  (249810646, 925591039),
#  (249810646, 925591039),
#  (249810646, 925591039),
#  (925591039, 37703152),
#  (925591039, 37703152),
#  (37703152, 427878668),
#  (427878668, 925611073),
#  (925611073, 249740752),
#  (249740752, 58707648),
#  (249740752, 58707648),
#  (249740752, 58707648),
#  (58707648, 58707655),
#  (58707648, 58707655),
#  (58707648, 58707655),
#  (58707648, 58707655),
#  (58707648, 58707655)]

# %%
i = 0
edg = []
for edge in edge_ids:
    index = edge_ids[i]
    tup = list(index)
    tup.append(0)
    ed = tuple(tup)
    edg.append(ed)
    i = i+1
edg
# Out:
# [(4017092106, 2705735628, 0),
#  (4017092106, 2705735628, 0),
#  (4017092106, 2705735628, 0),
#  (2705735628, 278156525, 0),
#  (278156525, 278156529, 0),
#  (278156529, 278156537, 0),
#  (278156537, 278156460, 0),
#  (278156460, 29041433, 0),
#  (278156460, 29041433, 0),
#  (278156460, 29041433, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (29041433, 277898402, 0),
#  (277898402, 277898418, 0),
#  (277898402, 277898418, 0),
#  (277898402, 277898418, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (277898418, 29041426, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (29041426, 277896979, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (277896979, 29041418, 0),
#  (29041418, 29041414, 0),
#  (29041418, 29041414, 0),
#  (29041418, 29041414, 0),
#  (29041418, 29041414, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (29041414, 277729693, 0),
#  (277729693, 277738641, 0),
#  (277738641, 277727478, 0),
#  (277727478, 277727457, 0),
#  (277727457, 54781716, 0),
#  (54781716, 302697571, 0),
#  (302697571, 302697583, 0),
#  (302697583, 54781758, 0),
#  (54781758, 256787271, 0),
#  (256787271, 302697586, 0),
#  (302697586, 254321187, 0),
#  (254321187, 302697589, 0),
#  (254321187, 302697589, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (302697589, 54781720, 0),
#  (54781720, 303364981, 0),
#  (54781720, 303364981, 0),
#  (303364981, 304637903, 0),
#  (303364981, 304637903, 0),
#  (303364981, 304637903, 0),
#  (303364981, 304637903, 0),
#  (303364981, 304637903, 0),
#  (304637903, 34924748, 0),
#  (304637903, 34924748, 0),
#  (304637903, 34924748, 0),
#  (304637903, 34924748, 0),
#  (304637903, 34924748, 0),
#  (34924748, 34924790, 0),
#  (34924748, 34924790, 0),
#  (34924748, 34924790, 0),
#  (34924748, 34924790, 0),
#  (34924748, 34924790, 0),
#  (34924748, 34924790, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (34924790, 7152154273, 0),
#  (7152154273, 33846185, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (33846185, 60676690, 0),
#  (60676690, 21518910, 0),
#  (60676690, 21518910, 0),
#  (60676690, 21518910, 0),
#  (21518910, 6425072711, 0),
#  (21518910, 6425072711, 0),
#  (21518910, 6425072711, 0),
#  (21518910, 6425072711, 0),
#  (21518910, 6425072711, 0),
#  (21518910, 6425072711, 0),
#  (6425072711, 6425072705, 0),
#  (6425072705, 945921131, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (945921131, 29041398, 0),
#  (29041398, 37703158, 0),
#  (37703158, 249810646, 0),
#  (249810646, 925591039, 0),
#  (249810646, 925591039, 0),
#  (249810646, 925591039, 0),
#  (925591039, 37703152, 0),
#  (925591039, 37703152, 0),
#  (37703152, 427878668, 0),
#  (427878668, 925611073, 0),
#  (925611073, 249740752, 0),
#  (249740752, 58707648, 0),
#  (249740752, 58707648, 0),
#  (249740752, 58707648, 0),
#  (58707648, 58707655, 0),
#  (58707648, 58707655, 0),
#  (58707648, 58707655, 0),
#  (58707648, 58707655, 0),
#  (58707648, 58707655, 0)]

# %%
import folium

lat = 51.950296032982756
lng = 7.615756988525391

# get the coordinates of the "best" mapmatched route
coords = [m.edge_m.pi[:] for m in matcher.lattice_best]

# plot both raw and mapmatched track
m = folium.Map(location=[lat, lng], zoom_start=13)
folium.PolyLine(coords, color='blue').add_to(m)
folium.PolyLine(track_coords, color='red').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
track_31['Edge'] = edg
track_31
# Out:
# C:\Users\sindh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                            id                 time                  geometry  \
# 0    5ddcdd4a44ea85025cfdf87a  2019-11-25T16:13:34  POINT (7.64831 51.94246)
# 1    5ddcdd4a44ea85025cfdf87c  2019-11-25T16:13:39  POINT (7.64831 51.94248)
# 2    5ddcdd4a44ea85025cfdf87d  2019-11-25T16:13:44  POINT (7.64808 51.94270)
# 3    5ddcdd4a44ea85025cfdf87e  2019-11-25T16:13:49  POINT (7.64769 51.94310)
# 4    5ddcdd4a44ea85025cfdf87f  2019-11-25T16:13:55  POINT (7.64738 51.94342)
# ..                        ...                  ...                       ...
# 238  5ddcdd4a44ea85025cfdf969  2019-11-25T16:33:36  POINT (7.59412 51.96520)
# 239  5ddcdd4a44ea85025cfdf96a  2019-11-25T16:33:41  POINT (7.59321 51.96524)
# 240  5ddcdd4a44ea85025cfdf96b  2019-11-25T16:33:46  POINT (7.59233 51.96528)
# 241  5ddcdd4a44ea85025cfdf96c  2019-11-25T16:33:51  POINT (7.59147 51.96533)
# 242  5ddcdd4a44ea85025cfdf96d  2019-11-25T16:33:56  POINT (7.59065 51.96538)
#
#      Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                  13.000000                      %   2.786892     kg/h
# 1                  20.891455                      %  10.765092     kg/h
# 2                  62.367647                      %  28.304836     kg/h
# 3                  13.000000                      %   2.944278     kg/h
# 4                  13.000000                      %   2.734270     kg/h
# ..                       ...                    ...        ...      ...
# 238                17.288630                      %   7.648827     kg/h
# 239                15.000000                      %   4.926580     kg/h
# 240                15.571428                      %   4.489400     kg/h
# 241                13.000000                      %   3.410955     kg/h
# 242                13.000000                      %   3.335400     kg/h
#
#      GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ... sensor.manufacturer  \
# 0          0.900000     precision         326.011243  ...       Mercedes Benz
# 1          0.953654     precision         329.524828  ...       Mercedes Benz
# 2          0.900000     precision         325.714825  ...       Mercedes Benz
# 3          0.958882     precision         328.816084  ...       Mercedes Benz
# 4          1.000000     precision         325.877407  ...       Mercedes Benz
# ..              ...           ...                ...  ...                 ...
# 238        1.049396     precision         280.133557  ...       Mercedes Benz
# 239        1.000000     precision         275.726263  ...       Mercedes Benz
# 240        1.000000     precision         276.580282  ...       Mercedes Benz
# 241        1.000000     precision         276.176601  ...       Mercedes Benz
# 242        1.036263     precision         276.668818  ...       Mercedes Benz
#
#      track.appVersion track.touVersion  O2 Lambda Voltage ER.value  \
# 0                 NaN              NaN                         NaN
# 1                 NaN              NaN                         NaN
# 2                 NaN              NaN                         NaN
# 3                 NaN              NaN                         NaN
# 4                 NaN              NaN                         NaN
# ..                ...              ...                         ...
# 238               NaN              NaN                         NaN
# 239               NaN              NaN                         NaN
# 240               NaN              NaN                         NaN
# 241               NaN              NaN                         NaN
# 242               NaN              NaN                         NaN
#
#     O2 Lambda Voltage ER.unit  MAF.value MAF.unit  O2 Lambda Voltage.value  \
# 0                         NaN        NaN      NaN                      NaN
# 1                         NaN        NaN      NaN                      NaN
# 2                         NaN        NaN      NaN                      NaN
# 3                         NaN        NaN      NaN                      NaN
# 4                         NaN        NaN      NaN                      NaN
# ..                        ...        ...      ...                      ...
# 238                       NaN        NaN      NaN                      NaN
# 239                       NaN        NaN      NaN                      NaN
# 240                       NaN        NaN      NaN                      NaN
# 241                       NaN        NaN      NaN                      NaN
# 242                       NaN        NaN      NaN                      NaN
#
#     O2 Lambda Voltage.unit                         Edge
# 0                      NaN  (4017092106, 2705735628, 0)
# 1                      NaN  (4017092106, 2705735628, 0)
# 2                      NaN  (4017092106, 2705735628, 0)
# 3                      NaN   (2705735628, 278156525, 0)
# 4                      NaN    (278156525, 278156529, 0)
# ..                     ...                          ...
# 238                    NaN      (58707648, 58707655, 0)
# 239                    NaN      (58707648, 58707655, 0)
# 240                    NaN      (58707648, 58707655, 0)
# 241                    NaN      (58707648, 58707655, 0)
# 242                    NaN      (58707648, 58707655, 0)
#
# [243 rows x 55 columns]

# %%
length = []
for edge in edg:
    len = graph.edges[edge]['length']
    
    length.append(len)
#length

# %%
track_31['length'] = length
track_31['coords'] = coords
track_31
# Out:
# C:\Users\sindh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\sindh\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            id                 time                  geometry  \
# 0    5ddcdd4a44ea85025cfdf87a  2019-11-25T16:13:34  POINT (7.64831 51.94246)
# 1    5ddcdd4a44ea85025cfdf87c  2019-11-25T16:13:39  POINT (7.64831 51.94248)
# 2    5ddcdd4a44ea85025cfdf87d  2019-11-25T16:13:44  POINT (7.64808 51.94270)
# 3    5ddcdd4a44ea85025cfdf87e  2019-11-25T16:13:49  POINT (7.64769 51.94310)
# 4    5ddcdd4a44ea85025cfdf87f  2019-11-25T16:13:55  POINT (7.64738 51.94342)
# ..                        ...                  ...                       ...
# 238  5ddcdd4a44ea85025cfdf969  2019-11-25T16:33:36  POINT (7.59412 51.96520)
# 239  5ddcdd4a44ea85025cfdf96a  2019-11-25T16:33:41  POINT (7.59321 51.96524)
# 240  5ddcdd4a44ea85025cfdf96b  2019-11-25T16:33:46  POINT (7.59233 51.96528)
# 241  5ddcdd4a44ea85025cfdf96c  2019-11-25T16:33:51  POINT (7.59147 51.96533)
# 242  5ddcdd4a44ea85025cfdf96d  2019-11-25T16:33:56  POINT (7.59065 51.96538)
#
#      Throttle Position.value Throttle Position.unit  CO2.value CO2.unit  \
# 0                  13.000000                      %   2.786892     kg/h
# 1                  20.891455                      %  10.765092     kg/h
# 2                  62.367647                      %  28.304836     kg/h
# 3                  13.000000                      %   2.944278     kg/h
# 4                  13.000000                      %   2.734270     kg/h
# ..                       ...                    ...        ...      ...
# 238                17.288630                      %   7.648827     kg/h
# 239                15.000000                      %   4.926580     kg/h
# 240                15.571428                      %   4.489400     kg/h
# 241                13.000000                      %   3.410955     kg/h
# 242                13.000000                      %   3.335400     kg/h
#
#      GPS VDOP.value GPS VDOP.unit  GPS Bearing.value  ... track.touVersion  \
# 0          0.900000     precision         326.011243  ...              NaN
# 1          0.953654     precision         329.524828  ...              NaN
# 2          0.900000     precision         325.714825  ...              NaN
# 3          0.958882     precision         328.816084  ...              NaN
# 4          1.000000     precision         325.877407  ...              NaN
# ..              ...           ...                ...  ...              ...
# 238        1.049396     precision         280.133557  ...              NaN
# 239        1.000000     precision         275.726263  ...              NaN
# 240        1.000000     precision         276.580282  ...              NaN
# 241        1.000000     precision         276.176601  ...              NaN
# 242        1.036263     precision         276.668818  ...              NaN
#
#      O2 Lambda Voltage ER.value O2 Lambda Voltage ER.unit  MAF.value MAF.unit  \
# 0                           NaN                       NaN        NaN      NaN
# 1                           NaN                       NaN        NaN      NaN
# 2                           NaN                       NaN        NaN      NaN
# 3                           NaN                       NaN        NaN      NaN
# 4                           NaN                       NaN        NaN      NaN
# ..                          ...                       ...        ...      ...
# 238                         NaN                       NaN        NaN      NaN
# 239                         NaN                       NaN        NaN      NaN
# 240                         NaN                       NaN        NaN      NaN
# 241                         NaN                       NaN        NaN      NaN
# 242                         NaN                       NaN        NaN      NaN
#
#      O2 Lambda Voltage.value O2 Lambda Voltage.unit  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ..                       ...                    ...
# 238                      NaN                    NaN
# 239                      NaN                    NaN
# 240                      NaN                    NaN
# 241                      NaN                    NaN
# 242                      NaN                    NaN
#
#                             Edge   length  \
# 0    (4017092106, 2705735628, 0)   94.748
# 1    (4017092106, 2705735628, 0)   94.748
# 2    (4017092106, 2705735628, 0)   94.748
# 3     (2705735628, 278156525, 0)   55.325
# 4      (278156525, 278156529, 0)    9.141
# ..                           ...      ...
# 238      (58707648, 58707655, 0)  305.139
# 239      (58707648, 58707655, 0)  305.139
# 240      (58707648, 58707655, 0)  305.139
# 241      (58707648, 58707655, 0)  305.139
# 242      (58707648, 58707655, 0)  305.139
#
#                                       coords
# 0     (51.94247886111485, 7.648358100522043)
# 1      (51.94249374481513, 7.64834357593001)
# 2    (51.94271402780464, 7.6481286065135885)
# 3      (51.9431178603529, 7.647735396234544)
# 4            (51.9435021, 7.647368099999999)
# ..                                       ...
# 238    (51.96507107823773, 7.59409514366242)
# 239   (51.96512926734402, 7.593191219183561)
# 240     (51.96518584145823, 7.5923122770633)
# 241   (51.96524092138721, 7.591456448965451)
# 242   (51.96529366507249, 7.590636828925059)
#
# [243 rows x 57 columns]

# %%
def avg(edge):
    speed = track_31[(track_31['Edge'] == edge)]['Speed.value'].mean()
    print('The average speed for the edge {} is {}'.format(edge,speed))

# %%
 print(track_31['Edge'].unique())
# Out:
# [(4017092106, 2705735628, 0) (2705735628, 278156525, 0)
#  (278156525, 278156529, 0) (278156529, 278156537, 0)
#  (278156537, 278156460, 0) (278156460, 29041433, 0)
#  (29041433, 277898402, 0) (277898402, 277898418, 0)
#  (277898418, 29041426, 0) (29041426, 277896979, 0)
#  (277896979, 29041418, 0) (29041418, 29041414, 0) (29041414, 277729693, 0)
#  (277729693, 277738641, 0) (277738641, 277727478, 0)
#  (277727478, 277727457, 0) (277727457, 54781716, 0)
#  (54781716, 302697571, 0) (302697571, 302697583, 0)
#  (302697583, 54781758, 0) (54781758, 256787271, 0)
#  (256787271, 302697586, 0) (302697586, 254321187, 0)
#  (254321187, 302697589, 0) (302697589, 54781720, 0)
#  (54781720, 303364981, 0) (303364981, 304637903, 0)
#  (304637903, 34924748, 0) (34924748, 34924790, 0)
#  (34924790, 7152154273, 0) (7152154273, 33846185, 0)
#  (33846185, 60676690, 0) (60676690, 21518910, 0) (21518910, 6425072711, 0)
#  (6425072711, 6425072705, 0) (6425072705, 945921131, 0)
#  (945921131, 29041398, 0) (29041398, 37703158, 0) (37703158, 249810646, 0)
#  (249810646, 925591039, 0) (925591039, 37703152, 0)
#  (37703152, 427878668, 0) (427878668, 925611073, 0)
#  (925611073, 249740752, 0) (249740752, 58707648, 0)
#  (58707648, 58707655, 0)]

# %%
if __name__ == '__main__':
    print("The average speed:")
    average_speed = avg((925611073, 249740752, 0))
# Out:
# The average speed:
# The average speed for the edge (925611073, 249740752, 0) is 42.0

# %% [raw]
# nodes_df, edge_df = ox.graph_to_gdfs(graph)

# %%
edge_df
# Out:
#                u           v  key                              osmid  \
# 0     2896166920  2896166784    0                          285975591
# 1     2896166926  2896166785    0                          285975587
# 2     5390434323  5390434370    0                          558856580
# 3     5390434323  5390434336    0             [558856586, 558885438]
# 4     2896166939  2896166786    0                          285975586
# ...          ...         ...  ...                                ...
# 9761   387858400    29041441    0  [377848593, 702531109, 665654343]
# 9762  7147306988  5465240364    0                          160290233
# 9763  7147306988  5242508998    0                          765238256
# 9764  7147306988  5465240361    0      [771101090, 7681235, 6279039]
# 9765  1797259253   293776601    0             [168462465, 371652300]
#
#                   name      highway maxspeed  oneway   length  \
# 0     Palestrinastraße  residential       30   False   26.116
# 1     Palestrinastraße  residential       30   False   25.730
# 2         Schlossplatz  residential       50   False    6.146
# 3         Schlossplatz    secondary       50    True  200.247
# 4     Palestrinastraße  residential       30   False   26.277
# ...                ...          ...      ...     ...      ...
# 9761   Albersloher Weg    secondary       50    True  137.175
# 9762  Wolbecker Straße    secondary       50   False   98.349
# 9763               NaN   trunk_link      NaN    True   51.604
# 9764  Wolbecker Straße    secondary       50   False  213.443
# 9765           Altehof  residential       30   False  173.321
#
#                                                geometry   lanes    ref bridge  \
# 0       LINESTRING (7.64487 51.98282, 7.64488 51.98259)     NaN    NaN    NaN
# 1       LINESTRING (7.64441 51.98285, 7.64442 51.98262)     NaN    NaN    NaN
# 2       LINESTRING (7.61792 51.96347, 7.61783 51.96347)     NaN    NaN    NaN
# 3     LINESTRING (7.61792 51.96347, 7.61792 51.96356...  [3, 2]    K 6    NaN
# 4       LINESTRING (7.64397 51.98288, 7.64397 51.98264)     NaN    NaN    NaN
# ...                                                 ...     ...    ...    ...
# 9761  LINESTRING (7.63685 51.95090, 7.63692 51.95083...  [1, 3]  L 586    NaN
# 9762  LINESTRING (7.66345 51.95308, 7.66327 51.95311...       3  L 793    NaN
# 9763  LINESTRING (7.66345 51.95308, 7.66340 51.95307...       1    NaN    NaN
# 9764  LINESTRING (7.66345 51.95308, 7.66366 51.95305...       3  L 793    yes
# 9765  LINESTRING (7.68083 51.92754, 7.68087 51.92748...     NaN    NaN    NaN
#
#      tunnel service access   width junction area
# 0       NaN     NaN    NaN     NaN      NaN  NaN
# 1       NaN     NaN    NaN     NaN      NaN  NaN
# 2       NaN     NaN    NaN     NaN      NaN  NaN
# 3       NaN     NaN    NaN     NaN      NaN  NaN
# 4       NaN     NaN    NaN     NaN      NaN  NaN
# ...     ...     ...    ...     ...      ...  ...
# 9761    NaN     NaN    NaN     NaN      NaN  NaN
# 9762    NaN     NaN    NaN     NaN      NaN  NaN
# 9763    NaN     NaN    NaN     NaN      NaN  NaN
# 9764    NaN     NaN    NaN     NaN      NaN  NaN
# 9765    NaN     NaN    NaN  [3, 2]      NaN  NaN
#
# [9766 rows x 19 columns]

# %%
graph.nodes['highway']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-02b08e539e6c> in <module>
# ----> 1 graph.nodes['highway']
#
# ~\anaconda3\lib\site-packages\networkx\classes\reportviews.py in __getitem__(self, n)
#     176
#     177     def __getitem__(self, n):
# --> 178         return self._nodes[n]
#     179
#     180     # Set methods
#
# KeyError: 'highway'

# %%
nodes_df.columns
# Out:
# Index(['y', 'x', 'osmid', 'highway', 'ref', 'geometry'], dtype='object')

# %%
nodes_df
# Out:
#                     y         x       osmid          highway  ref  \
# 2896166920  51.982822  7.644870  2896166920              NaN  NaN
# 2896166926  51.982847  7.644408  2896166926              NaN  NaN
# 5390434323  51.963468  7.617924  5390434323  traffic_signals  NaN
# 2896166939  51.982881  7.643966  2896166939              NaN  NaN
# 5390434336  51.965259  7.617681  5390434336  traffic_signals  NaN
# ...               ...       ...         ...              ...  ...
# 2705735628  51.943073  7.647778  2705735628              NaN  NaN
# 2600583118  51.989670  7.646560  2600583118              NaN  NaN
# 387858400   51.950897  7.636848   387858400  traffic_signals  NaN
# 7147306988  51.953085  7.663449  7147306988  traffic_signals  NaN
# 1797259253  51.927543  7.680826  1797259253              NaN  NaN
#
#                             geometry
# 2896166920  POINT (7.64487 51.98282)
# 2896166926  POINT (7.64441 51.98285)
# 5390434323  POINT (7.61792 51.96347)
# 2896166939  POINT (7.64397 51.98288)
# 5390434336  POINT (7.61768 51.96526)
# ...                              ...
# 2705735628  POINT (7.64778 51.94307)
# 2600583118  POINT (7.64656 51.98967)
# 387858400   POINT (7.63685 51.95090)
# 7147306988  POINT (7.66345 51.95308)
# 1797259253  POINT (7.68083 51.92754)
#
# [4200 rows x 6 columns]

# %%
street_list =[]
import requests
for i in coords:
    
    #latlong from dataframe
    r,s = i[1], i[0]
    x = requests.get("http://router.project-osrm.org/nearest/v1/driving/{},{}?number=3&bearings=0,20".format(r,s))
    x = x.json()
    street_list.append(x['waypoints'][2]['name'])
    print(x['waypoints'][2]['name'])
print(street_list)
